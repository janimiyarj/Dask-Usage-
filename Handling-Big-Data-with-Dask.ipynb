# %%
# !pip install dask nltk graphviz
# Out:
# Requirement already satisfied: dask in /home/ryan/.local/lib/python3.10/site-packages (2024.5.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (7.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from dask) (5.4.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (2024.5.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (3.0.0)
# Requirement already satisfied: partd>=1.2.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (23.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (0.12.1)
# Requirement already satisfied: click>=8.1 in /home/ryan/.local/lib/python3.10/site-packages (from dask) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.13.0->dask) (1.0.0)
# Requirement already satisfied: locket in /home/ryan/.local/lib/python3.10/site-packages (from partd>=1.2.0->dask) (1.0.0)

# %% [markdown]
# ## Import Python Libtraries for BIg Data

# %%
# Dask components
import dask.dataframe as dd
import dask.array as da
from dask import delayed, compute

import pandas as pd
import numpy as np

# Import natural language library
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
# Out:
# /home/ryan/.local/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# [nltk_data] Downloading package wordnet to /home/ryan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Import Our Data

# %%
movies_df = dd.read_csv(
    'movies.csv',
    blocksize = '1MB' ,
    sample = 5000  ,
)
movies_pd = movies_df.compute()

movies_df
# Out:
# Dask DataFrame Structure:
#               Unnamed: 0     id   title  genres original_language overview popularity production_companies release_date   budget  revenue  runtime  status tagline vote_average vote_count credits keywords poster_path backdrop_path recommendations release_date_new
# npartitions=5
#                    int64  int64  string  string            string   string    float64               string       string  float64  float64  float64  string  string      float64    float64  string   string      string        string          string           string
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...
# ...                  ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...
# Dask Name: to_pyarrow_string, 2 graph layers
# /home/ryan/.local/lib/python3.10/site-packages/dask/dataframe/core.py:8393: UserWarning: Insufficient elements for `head`. 20 elements requested, only 0 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(

# %%
print(type(movies_df), type(movies_pd))
# Out:
# <class 'dask.dataframe.core.DataFrame'> <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Missing Values Calculation

# %%
task_missing = movies_df.isnull().sum()

# Compute the task graph
task_missing.compute()
# Out:
# Unnamed: 0                 0
# id                         0
# title                      0
# genres                     0
# original_language          0
# overview                 489
# popularity                 0
# production_companies    2197
# release_date             266
# budget                     0
# revenue                    0
# runtime                   81
# status                     0
# tagline                 5129
# vote_average               0
# vote_count                 0
# credits                  324
# keywords                4010
# poster_path              785
# backdrop_path           3385
# recommendations         6623
# release_date_new         266
# dtype: int64

# %%
task_missing.visualize(engine = "cytoscape")
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'rankDir': 'BT', 'nodeSep': 10, 'edgeSep': 10, 'spacingFact…

# %% [markdown]
# ## Creating Datetime Features from Strings

# %%
movies_df['release_date_dt'] = dd.to_datetime(
    movies_df['release_date'], errors='coerce' ,
    exact = False, format = '%Y-%m-%d'
)

# %% [markdown]
# ## Engineer a Year, Month, and Day of the Week String features

# %%
movies_df['year'] = movies_df['release_date_dt'].dt.strftime('%Y')  # Year
movies_df['month'] = movies_df['release_date_dt'].dt.strftime('%b')  # Abbreviated named of month
movies_df['day_of_week'] = movies_df['release_date_dt'].dt.strftime('%a')  # Abbreviated day of the week

# %%
movies_df.head(2)
# Out:
#    Unnamed: 0      id                     title  \
# 0          12  594767  Shazam! Fury of the Gods
# 1          18  615656         Meg 2: The Trench
#
#                                  genres original_language  \
# 0       action-comedy-fantasy-adventure                en
# 1  action-science fiction-horror-comedy                en
#
#                                             overview  popularity  \
# 0  Billy Batson and his foster siblings who trans...     2010.98
# 1  An exploratory dive into the deepest depths of...     1321.17
#
#                                 production_companies release_date  \
# 0        New Line Cinema-The Safran Company-DC Films   2023-03-15
# 1  Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
#
#         budget  ...                                            credits  \
# 0  125000000.0  ...  Zachary Levi-Asher Angel-Jack Dylan Grazer-Rac...
# 1  129000000.0  ...  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
#
#                                             keywords  \
# 0  superhero-end of the world-super power-aftercr...
# 1                based on novel or book-sequel-kaiju
#
#                         poster_path                     backdrop_path  \
# 0  /A3ZbZsmsvNGdprRi2lKgGEeVLEH.jpg  /nDxJJyA5giRhXx96q1sWbOUjMBI.jpg
# 1  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /Aukfa8dk6B5OxuelbaPBOJYXaBI.jpg
#
#                                      recommendations  release_date_new  \
# 0  868759-994751-700391-948713-502356-938992-7660...        2023-03-15
# 1  447277-872585-346698-1083862-496450-457332-114...        2023-08-02
#
#   release_date_dt  year month day_of_week
# 0      2023-03-15  2023   Mar         Wed
# 1      2023-08-02  2023   Aug         Wed
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Filter by Datetime Intervals & Sort Our Data

# %%
# %%time

# Filter by time index between 2016 and 2024 (time interval)
filtered_df = movies_df.loc[
    (movies_df['release_date_dt'] > '2015-12-31') & (movies_df['release_date_dt'] < '2024'), :
].compute().sort_values(['budget', 'release_date_dt'], ascending=False)  # persist to memory and THEN sort the values by budget & date


print(f'Number of matching observations: {len(filtered_df)}')
filtered_df.head(5)
# Out:
# Number of matching observations: 2539
# CPU times: user 333 ms, sys: 63.5 ms, total: 397 ms
# Wall time: 349 ms
#     Unnamed: 0      id                                  title  \
# 6           77  616037                 Thor: Love and Thunder
# 27         335  508943                                   Luca
# 83        1491  508439                                 Onward
# 28         341  384018  Fast & Furious Presents: Hobbs & Shaw
# 25         296  436969                      The Suicide Squad
#
#                                               genres original_language  \
# 6                              fantasy-action-comedy                en
# 27  animation-comedy-family-fantasy-action-adventure                en
# 83  family-animation-adventure-comedy-fantasy-action                en
# 28                           action-adventure-comedy                en
# 25                           action-comedy-adventure                en
#
#                                              overview  popularity  \
# 6   After his retirement is interrupted by Gorr th...     394.087
# 27  Luca and his best friend Alberto experience an...     132.456
# 83  In a suburban fantasy world two teenage elf br...      47.176
# 28  Ever since US Diplomatic Security Service Agen...     130.097
# 25  Supervillains Harley Quinn Bloodsport Peacemak...     144.638
#
#                                  production_companies release_date  \
# 6              Marvel Studios-Kevin Feige Productions   2022-07-06
# 27                         Pixar-Walt Disney Pictures   2021-06-17
# 83                         Walt Disney Pictures-Pixar   2020-02-29
# 28  Universal Pictures-Chris Morgan Productions-Se...   2019-08-01
# 25  DC Films-Atlas Entertainment-The Safran Compan...   2021-07-28
#
#          budget  ...                                            credits  \
# 6   250000000.0  ...  Chris Hemsworth-Natalie Portman-Christian Bale...
# 27  200000000.0  ...  Jacob Tremblay-Jack Dylan Grazer-Emma Berman-S...
# 83  200000000.0  ...  Tom Holland-Chris Pratt-Julia Louis-Dreyfus-Oc...
# 28  200000000.0  ...  Dwayne Johnson-Jason Statham-Idris Elba-Vaness...
# 25  185000000.0  ...  Margot Robbie-Idris Elba-John Cena-Joel Kinnam...
#
#                                              keywords  \
# 6   ex-girlfriend-hero-greek mythology-sequel-supe...
# 27  italy-monster-friendship-friends-coming of age...
# 83  elves-magic-dead father-dead parent-fantasy wo...
# 28  london england-biological weapon-secret organi...
# 25  monster-anti hero-secret mission-superhero-bas...
#
#                          poster_path                     backdrop_path  \
# 6   /pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg  /jsoz1HlxczSuTx0mDl2h0lxy36l.jpg
# 27  /8tABCBpzu3mZbzMB3sRzMEHEvJi.jpg  /620hnMVLu6RSZW6a5rwO8gqpt0t.jpg
# 83  /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg
# 28  /qRyy2UmjC5ur9bDi3kpNNRCc5nc.jpg  /hpgda6P9GutvdkDX5MUJ92QG9aj.jpg
# 25   /kb4s0ML0iVZlG6wAKbbs9NAm6X.jpg  /jlGmlFOcfo8n5tURmhC7YVd4Iyy.jpg
#
#                                       recommendations  release_date_new  \
# 6   539681-610150-985939-629176-2-45920-438148-782...        2022-07-06
# 27  527774-77742-79233-337404-800409-497698-400216...        2021-06-17
# 83  726166-662018-872325-611059-1038789-579955-454...        2020-02-29
# 28  337339-429617-458156-423204-420818-168259-9615...        2019-08-01
# 25  451048-497698-385128-550988-193414-566525-7913...        2021-07-28
#
#    release_date_dt  year month day_of_week
# 6       2022-07-06  2022   Jul         Wed
# 27      2021-06-17  2021   Jun         Thu
# 83      2020-02-29  2020   Feb         Sat
# 28      2019-08-01  2019   Aug         Thu
# 25      2021-07-28  2021   Jul         Wed
#
# [5 rows x 26 columns]

# %%
movies_df
# Out:
# Dask DataFrame Structure:
#               Unnamed: 0     id   title  genres original_language overview popularity production_companies release_date   budget  revenue  runtime  status tagline vote_average vote_count credits keywords poster_path backdrop_path recommendations release_date_new release_date_dt    year   month day_of_week
# npartitions=5
#                    int64  int64  string  string            string   string    float64               string       string  float64  float64  float64  string  string      float64    float64  string   string      string        string          string           string  datetime64[ns]  string  string      string
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...             ...     ...     ...         ...
# ...                  ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...             ...     ...     ...         ...
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...             ...     ...     ...         ...
#                      ...    ...     ...     ...               ...      ...        ...                  ...          ...      ...      ...      ...     ...     ...          ...        ...     ...      ...         ...           ...             ...              ...             ...     ...     ...         ...
# Dask Name: assign, 25 graph layers

# %% [markdown]
# ## Aggregate Total Movie Budget by Year

# %%
# %%time

# Aggregation by year to find the total sum of movie budgets, computed it, and then we sorted the Pandas Series
budget_summation = movies_df.groupby('year').agg(
    {
        'budget': 'sum'
    }
).compute().sort_values(by = ['budget'] , ascending = False)

budget_summation
# budget_summation.visualize(engine='cytoscape')
# Out:
# CPU times: user 241 ms, sys: 93.1 ms, total: 334 ms
# Wall time: 305 ms
#             budget
# year
# 2013  1.141693e+09
# 2016  1.126214e+09
# 2022  1.108168e+09
# 2017  1.098265e+09
# 2010  1.097269e+09
# ...            ...
# 1939  0.000000e+00
# 1932  0.000000e+00
# 1945  0.000000e+00
# 1927  0.000000e+00
# 1959  0.000000e+00
#
# [119 rows x 1 columns]

# %% [markdown]
# ### Text Mining for Movie Descriptions

# %%
def find_synonyms(word_list) :
    all_matches = []

    for i in range(0, len(word_list)) :
        synonyms = []
        word = word_list[i]
        word_nltk = wordnet.synsets(word)
        for synonym in word_nltk :
            for lemma in synonym.lemmas() :
                name = str(lemma.name())
                name = name.replace('_', ' ')
                synonyms.append(name)

        synonyms_set = list(set(synonyms))
        all_matches.append(synonyms_set)

    # Escape the for-loop and flatten our list of synonyms to one single list
    flat_list = []
    for sublist in all_matches :
        for element in sublist :
            flat_list.append(element)
    return list(set(flat_list))

# %% [markdown]
# ### List of Synonyms

# %%
word_list = ['happy', 'joy', 'good', 'nice', 'comedy', 'kid']

synonym_list = find_synonyms(word_list)

# %% [markdown]
# ## Search for Matching Movie Genres

# %%
# %%time

# Converting strings to all lower-case
movies_df['genres'] = movies_df['genres'].str.lower()

# Concatenate our list of synonyms into one string....seperate by '|'
synonym_string ='|'.join(synonym_list)
synonym_string

# String-based matching search
feel_good_df = movies_df.loc[movies_df['genres'].str.contains(synonym_string), :]

filtered_movies_df = feel_good_df.compute().sort_values(by=['popularity'], ascending=False)
filtered_movies_df
# Out:
# CPU times: user 288 ms, sys: 114 ms, total: 402 ms
# Wall time: 359 ms
#      Unnamed: 0      id                                title  \
# 0            12  594767             Shazam! Fury of the Gods
# 1            18  615656                    Meg 2: The Trench
# 2            19  868759                              Ghosted
# 3            22  758009                      Shotgun Wedding
# 4            48  587092                         Unicorn Wars
# ..          ...     ...                                  ...
# 978       90620  789367                          Spy Catcher
# 977       90590  789096                              Mancoro
# 976       90153  789339           Mad Martha: Church Warrior
# 975       89662  757541  Uchuu Sentai Kyuranger: Final Stage
# 989       92300  787033                  The Art of the Deal
#
#                                          genres original_language  \
# 0               action-comedy-fantasy-adventure                en
# 1          action-science fiction-horror-comedy                en
# 2                         romance-action-comedy                en
# 3                         action-romance-comedy                en
# 4    action-animation-comedy-fantasy-horror-war                es
# ..                                          ...               ...
# 978                     comedy-action-adventure                en
# 977             action-fantasy-animation-comedy                id
# 976                        action-comedy-horror                en
# 975       fantasy-science fiction-action-comedy                ja
# 989                       thriller-crime-comedy                en
#
#                                               overview  popularity  \
# 0    Billy Batson and his foster siblings who trans...    2010.980
# 1    An exploratory dive into the deepest depths of...    1321.170
# 2    Salt-of-the-earth Cole falls head over heels f...    1214.867
# 3    Darcy and Tom gather their families for the ul...    1043.225
# 4    An army of bear cubs train and indoctrinate yo...     535.524
# ..                                                 ...         ...
# 978  Natasha finds out that her handler has gone ba...       0.600
# 977  Mas Bejo who was too much in arrears was taken...       0.600
# 976  A B-movie horror-comedy set in a post-apocalyp...       0.600
# 975  Annual Super Sentai stage show featuring the c...       0.600
# 989  A struggling real estate developer has one las...       0.600
#
#                                   production_companies release_date  \
# 0          New Line Cinema-The Safran Company-DC Films   2023-03-15
# 1    Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 2                         Skydance Media-Apple Studios   2023-04-18
# 3    Lionsgate-Mandeville Films-Nuyorican Productio...   2022-12-28
# 4    UniKo-Schmuby Productions-Autour de Minuit-Pan...   2022-10-21
# ..                                                 ...          ...
# 978                                               <NA>         <NA>
# 977                                        Javora Film   2020-12-05
# 976                                               <NA>   2017-07-08
# 975                                       Toei Company   2017-12-06
# 989                                               <NA>   2020-04-22
#
#           budget  ...                                            credits  \
# 0    125000000.0  ...  Zachary Levi-Asher Angel-Jack Dylan Grazer-Rac...
# 1    129000000.0  ...  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 2            0.0  ...  Chris Evans-Ana de Armas-Adrien Brody-Mike Moh...
# 3            0.0  ...  Jennifer Lopez-Josh Duhamel-Jennifer Coolidge-...
# 4            0.0  ...  Jon Goiri-Jaione Insausti-Ramón Barea-Txema Re...
# ..           ...  ...                                                ...
# 978          0.0  ...  Elan Andreassen-Andii Zhebrovskyi-Abbey St. Br...
# 977          0.0  ...                             Gugun Arief-Wah Rahayu
# 976          0.0  ...  Ellen Williams-Andrew Hunsicker-Kerwin Gonzale...
# 975          0.0  ...  Takumi Kizu-Yousuke Kishi-Kazuya Nakai-Yuki On...
# 989          7.0  ...  Maclean Kelley-Isaiah Shavers-Will Nelson-Anna...
#
#                                               keywords  \
# 0    superhero-end of the world-super power-aftercr...
# 1                  based on novel or book-sequel-kaiju
# 2                                         secret agent
# 3                            wedding-hostage situation
# 4                      gore-bear-unicorn-war-animation
# ..                                                 ...
# 978                                               <NA>
# 977                                               <NA>
# 976                          mad martha-church warrior
# 975  ranger-stage show-superhero-space-squadron-sup...
# 989                                               <NA>
#
#                           poster_path                     backdrop_path  \
# 0    /A3ZbZsmsvNGdprRi2lKgGEeVLEH.jpg  /nDxJJyA5giRhXx96q1sWbOUjMBI.jpg
# 1    /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /Aukfa8dk6B5OxuelbaPBOJYXaBI.jpg
# 2    /liLN69YgoovHVgmlHJ876PKi5Yi.jpg  /b9UCfDzwiWw7mIFsIQR9ZJUeh7q.jpg
# 3    /t79ozwWnwekO0ADIzsFP1E5SkvR.jpg  /zGoZB4CboMzY1z4G3nU6BWnMDB2.jpg
# 4    /8KBj11zBaRdhoeq1q9jcAwKmDSk.jpg  /rbUPJoJJquPbX1AiV6GzOqcmJME.jpg
# ..                                ...                               ...
# 978                              <NA>                              <NA>
# 977  /hPyeLIcKPDQya0R84z0HelQJ1p7.jpg                              <NA>
# 976  /lz1VeCYWSugjDxzk978o7LM7NAr.jpg                              <NA>
# 975  /vPELafsbRkCNMRkwulggM0HIc38.jpg                              <NA>
# 989  /30ZDnjM9lEtcLcb7GN56ZAlVsP7.jpg                              <NA>
#
#                                        recommendations  release_date_new  \
# 0    868759-994751-700391-948713-502356-938992-7660...        2023-03-15
# 1    447277-872585-346698-1083862-496450-457332-114...        2023-08-02
# 2                                        640146-726759        2023-04-18
# 3    702432-1064489-1013870-953734-805307-753965-84...        2022-12-28
# 4                                        852046-601796        2022-10-21
# ..                                                 ...               ...
# 978                                               <NA>              <NA>
# 977                                               <NA>        2020-12-05
# 976                                               <NA>        2017-07-08
# 975                                               <NA>        2017-12-06
# 989                                               <NA>        2020-04-22
#
#     release_date_dt  year month day_of_week
# 0        2023-03-15  2023   Mar         Wed
# 1        2023-08-02  2023   Aug         Wed
# 2        2023-04-18  2023   Apr         Tue
# 3        2022-12-28  2022   Dec         Wed
# 4        2022-10-21  2022   Oct         Fri
# ..              ...   ...   ...         ...
# 978             NaT  <NA>  <NA>        <NA>
# 977      2020-12-05  2020   Dec         Sat
# 976      2017-07-08  2017   Jul         Sat
# 975      2017-12-06  2017   Dec         Wed
# 989      2020-04-22  2020   Apr         Wed
#
# [8078 rows x 26 columns]
